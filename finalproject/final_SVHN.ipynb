# %%
# %%bash
# pip install --upgrade --no-deps theano
# Out:
# Requirement already up-to-date: theano in /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages

# %%
# %%bash
# pip install keras

# %%
import numpy
import matplotlib.pyplot as plt
import pylab

import theano.tensor as T
from theano.tensor.shared_randomstreams import RandomStreams
import pandas as pd
import os

from final_utils import *
from final_nn import *
from final import *

# %matplotlib inline
# Out:
# Using gpu device 0: GRID K520 (CNMeM is disabled, cuDNN Version is too old. Update to v5, was 3007.)
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")

# %% [markdown]
# # SVHN Tests

# %% [markdown]
# #### binary = False, output = Logistic

# %%
W_layer_0, Wb_layer_0 = test_bc(initial_learning_rate=0.01, final_learning_rate=.01*(0.000003/.01)**(15/200), n_epochs=15, 
                        nkerns=[64, 64, 128, 128, 256, 256], batch_size=50, verbose=False, 
                        stochastic=False, binary=False, which_data='svhn', outputlayer='Logistic')
# Out:
# Loading svhn data with Logistic output layer
# ... building the model
# Using logistic regression
# ... training
# epoch 1 errors printing to LRout_svhn_errors.csv
# epoch 2 errors printing to LRout_svhn_errors.csv
# epoch 3 errors printing to LRout_svhn_errors.csv
# epoch 4 errors printing to LRout_svhn_errors.csv
# epoch 5 errors printing to LRout_svhn_errors.csv
# epoch 6 errors printing to LRout_svhn_errors.csv
# epoch 7 errors printing to LRout_svhn_errors.csv
# epoch 8 errors printing to LRout_svhn_errors.csv
# epoch 9 errors printing to LRout_svhn_errors.csv
# epoch 10 errors printing to LRout_svhn_errors.csv
# epoch 11 errors printing to LRout_svhn_errors.csv
# epoch 12 errors printing to LRout_svhn_errors.csv
# epoch 13 errors printing to LRout_svhn_errors.csv
# epoch 14 errors printing to LRout_svhn_errors.csv
# epoch 15 errors printing to LRout_svhn_errors.csv
# Optimization complete.
# ...

# %%
f,ax=plt.subplots(8,8, figsize=(8,8))
for i in range(8):
    for j in range(8):
        ax[i,j].imshow(W_layer_0[i*8+j,:,:,:].transpose(1,2,0))
        ax[i,j].axis('off')

# %% [markdown]
# #### binary = False, output = SVM

# %%
W_layer_0, Wb_layer_0 = test_bc(initial_learning_rate=0.01, final_learning_rate=.01*(0.000003/.01)**(15/200), n_epochs=15, 
                        nkerns=[64, 64, 128, 128, 256, 256], batch_size=50, verbose=False, 
                        stochastic=False, binary=False, which_data='svhn', outputlayer='svm')
# Out:
# Loading svhn data with svm output layer
# ... building the model
# Using Support Vector Machines
# ... training
# epoch 1 errors printing to svmout_svhn_errors.csv
# epoch 2 errors printing to svmout_svhn_errors.csv
# epoch 3 errors printing to svmout_svhn_errors.csv
# epoch 4 errors printing to svmout_svhn_errors.csv
# epoch 5 errors printing to svmout_svhn_errors.csv
# epoch 6 errors printing to svmout_svhn_errors.csv
# epoch 7 errors printing to svmout_svhn_errors.csv
# epoch 8 errors printing to svmout_svhn_errors.csv
# epoch 9 errors printing to svmout_svhn_errors.csv
# epoch 10 errors printing to svmout_svhn_errors.csv
# epoch 11 errors printing to svmout_svhn_errors.csv
# epoch 12 errors printing to svmout_svhn_errors.csv
# epoch 13 errors printing to svmout_svhn_errors.csv
# epoch 14 errors printing to svmout_svhn_errors.csv
# epoch 15 errors printing to svmout_svhn_errors.csv
# Optimization complete.
# ...

# %%
f,ax=plt.subplots(8,8, figsize=(8,8))
for i in range(8):
    for j in range(8):
        ax[i,j].imshow(W_layer_0[i*8+j,:,:,:].transpose(1,2,0))
        ax[i,j].axis('off')

# %% [markdown]
# #### binary = True, stochastic = False, output = Logistic

# %%
W_layer_0, Wb_layer_0 = test_bc(initial_learning_rate=0.01, final_learning_rate=.01*(0.000003/.01)**(15/200), n_epochs=15, 
                        nkerns=[64, 64, 128, 128, 256, 256], batch_size=50, verbose=False, 
                        stochastic=False, binary=True, which_data='svhn', outputlayer='Logistic')
# Out:
# Loading svhn data with Logistic output layer
# ... building the model
# Using logistic regression
# ... training
# epoch 1 errors printing to LRout_bin_deterministic_svhn_errors.csv
# epoch 2 errors printing to LRout_bin_deterministic_svhn_errors.csv
# epoch 3 errors printing to LRout_bin_deterministic_svhn_errors.csv
# epoch 4 errors printing to LRout_bin_deterministic_svhn_errors.csv
# epoch 5 errors printing to LRout_bin_deterministic_svhn_errors.csv
# epoch 6 errors printing to LRout_bin_deterministic_svhn_errors.csv
# epoch 7 errors printing to LRout_bin_deterministic_svhn_errors.csv
# epoch 8 errors printing to LRout_bin_deterministic_svhn_errors.csv
# epoch 9 errors printing to LRout_bin_deterministic_svhn_errors.csv
# epoch 10 errors printing to LRout_bin_deterministic_svhn_errors.csv
# epoch 11 errors printing to LRout_bin_deterministic_svhn_errors.csv
# epoch 12 errors printing to LRout_bin_deterministic_svhn_errors.csv
# ...

# %%
f,ax=plt.subplots(8,8, figsize=(8,8))
for i in range(8):
    for j in range(8):
        ax[i,j].imshow(W_layer_0[i*8+j,:,:,:].transpose(1,2,0))
        ax[i,j].axis('off')

# %% [markdown]
# #### binary = True, stochastic = True, output = Logistic

# %%
W_layer_0, Wb_layer_0 = test_bc(initial_learning_rate=0.01, final_learning_rate=.01*(0.000003/.01)**(15/200), n_epochs=15, 
                        nkerns=[64, 64, 128, 128, 256, 256], batch_size=50, verbose=False, 
                        stochastic=True, binary=True, which_data='svhn', outputlayer='Logistic')
# Out:
# Loading svhn data with Logistic output layer
# ... building the model
# Using logistic regression
# ... training
# epoch 1 errors printing to LRout_bin_stochastic_svhn_errors.csv
# epoch 2 errors printing to LRout_bin_stochastic_svhn_errors.csv
# epoch 3 errors printing to LRout_bin_stochastic_svhn_errors.csv
# epoch 4 errors printing to LRout_bin_stochastic_svhn_errors.csv
# epoch 5 errors printing to LRout_bin_stochastic_svhn_errors.csv
# epoch 6 errors printing to LRout_bin_stochastic_svhn_errors.csv
# epoch 7 errors printing to LRout_bin_stochastic_svhn_errors.csv
# epoch 8 errors printing to LRout_bin_stochastic_svhn_errors.csv
# epoch 9 errors printing to LRout_bin_stochastic_svhn_errors.csv
# epoch 10 errors printing to LRout_bin_stochastic_svhn_errors.csv
# epoch 11 errors printing to LRout_bin_stochastic_svhn_errors.csv
# epoch 12 errors printing to LRout_bin_stochastic_svhn_errors.csv
# epoch 13 errors printing to LRout_bin_stochastic_svhn_errors.csv
# ...

# %%
f,ax=plt.subplots(8,8, figsize=(8,8))
for i in range(8):
    for j in range(8):
        ax[i,j].imshow(W_layer_0[i*8+j,:,:,:].transpose(1,2,0))
        ax[i,j].axis('off')

# %% [markdown]
# #### binary = True, stochastic = False, output = SVM

# %%
W_layer_0, Wb_layer_0 = test_bc(initial_learning_rate=0.01, final_learning_rate=.01*(0.000003/.01)**(15/200), n_epochs=15, 
                        nkerns=[64, 64, 128, 128, 256, 256], batch_size=50, verbose=False, 
                        stochastic=False, binary=True, which_data='svhn', outputlayer='svm')
# Out:
# Loading svhn data with svm output layer
# ... building the model
# Using Support Vector Machines
# ... training
# epoch 1 errors printing to svmout_bin_deterministic_svhn_errors.csv
# epoch 2 errors printing to svmout_bin_deterministic_svhn_errors.csv
# epoch 3 errors printing to svmout_bin_deterministic_svhn_errors.csv
# epoch 4 errors printing to svmout_bin_deterministic_svhn_errors.csv
# epoch 5 errors printing to svmout_bin_deterministic_svhn_errors.csv
# epoch 6 errors printing to svmout_bin_deterministic_svhn_errors.csv
# epoch 7 errors printing to svmout_bin_deterministic_svhn_errors.csv
# epoch 8 errors printing to svmout_bin_deterministic_svhn_errors.csv
# epoch 9 errors printing to svmout_bin_deterministic_svhn_errors.csv
# epoch 10 errors printing to svmout_bin_deterministic_svhn_errors.csv
# epoch 11 errors printing to svmout_bin_deterministic_svhn_errors.csv
# epoch 12 errors printing to svmout_bin_deterministic_svhn_errors.csv
# ...

# %%
f,ax=plt.subplots(8,8, figsize=(8,8))
for i in range(8):
    for j in range(8):
        ax[i,j].imshow(W_layer_0[i*8+j,:,:,:].transpose(1,2,0))
        ax[i,j].axis('off')

# %% [markdown]
# #### binary = True, stochastic = True, output = SVM

# %%
W_layer_0, Wb_layer_0 = test_bc(initial_learning_rate=0.01, final_learning_rate=.01*(0.000003/.01)**(15/200), n_epochs=15, 
                        nkerns=[64, 64, 128, 128, 256, 256], batch_size=50, verbose=False, 
                        stochastic=True, binary=True, which_data='svhn', outputlayer='svm')
# Out:
# Loading svhn data with svm output layer
# ... building the model
# Using Support Vector Machines
# ... training
# epoch 1 errors printing to svmout_bin_stochastic_svhn_errors.csv
# epoch 2 errors printing to svmout_bin_stochastic_svhn_errors.csv
# epoch 3 errors printing to svmout_bin_stochastic_svhn_errors.csv
# epoch 4 errors printing to svmout_bin_stochastic_svhn_errors.csv
# epoch 5 errors printing to svmout_bin_stochastic_svhn_errors.csv
# epoch 6 errors printing to svmout_bin_stochastic_svhn_errors.csv
# epoch 7 errors printing to svmout_bin_stochastic_svhn_errors.csv
# epoch 8 errors printing to svmout_bin_stochastic_svhn_errors.csv
# epoch 9 errors printing to svmout_bin_stochastic_svhn_errors.csv
# epoch 10 errors printing to svmout_bin_stochastic_svhn_errors.csv
# epoch 11 errors printing to svmout_bin_stochastic_svhn_errors.csv
# epoch 12 errors printing to svmout_bin_stochastic_svhn_errors.csv
# epoch 13 errors printing to svmout_bin_stochastic_svhn_errors.csv
# ...

# %%
f,ax=plt.subplots(8,8, figsize=(8,8))
for i in range(8):
    for j in range(8):
        ax[i,j].imshow(W_layer_0[i*8+j,:,:,:].transpose(1,2,0))
        ax[i,j].axis('off')

# %% [markdown]
# ### Plots

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy
# %matplotlib inline

# %%
perf_files = ['LRout_svhn_errors.csv',
             'svmout_svhn_errors.csv',
             'LRout_bin_stochastic_svhn_errors.csv',
             'LRout_bin_deterministic_svhn_errors.csv',
             'svmout_bin_stochastic_svhn_errors.csv',
             'svmout_bin_deterministic_svhn_errors.csv'
            ]
perf_filenames = ['Logistic Output Layer without Binary Connect',
                 'SVM Output Layer without Binary Connect',
                 'Logistic Output Layer with Stochastic Binary Connect',
                 'Logistic Output Layer with Deterministic Binary Connect',
                 'SVM Output Layer with Stochastic Binary Connect',
                 'SVM Output Layer with Deterministic Binary Connect'
                ]
pdic = {}
for i, pfile in enumerate(perf_files):
    pdic['m'+str(i)] = pd.read_csv('./output/'+pfile)

# %%
n = 1000
for i, pfile in enumerate(perf_filenames):
    m = 'm'+str(i)
    plt.figure(figsize=(8,5))
    plt.plot(pdic[m].epoch[0:n], pdic[m].test_score[0:n], label='Test')
    plt.plot(pdic[m].epoch[0:n], pdic[m].this_validation_loss[0:n], label='Validation')
    plt.plot(pdic[m].epoch[0:n], pdic[m].this_training_loss[0:n], label='Training')
    plt.title("SVHN Model performance \n"+pfile)
    plt.ylabel('Classification Error (%)')
    plt.xlabel('Number of epochs')
    plt.legend()
    plt.grid()
    plt.show()

# %%
for (filex, filename) in zip(perf_filenames, perf_files):
    df = pd.read_csv('output/'+filename)
    print filex,'had a test error of' , df.ix[df.this_validation_loss.argmin(),'test_score']*100
# Out:
# Logistic Output Layer without Binary Connect had a test error of 10.8461538462
# SVM Output Layer without Binary Connect had a test error of 14.4807692308
# Logistic Output Layer with Stochastic Binary Connect had a test error of 11.5307692308
# Logistic Output Layer with Deterministic Binary Connect had a test error of 10.5115384615
# SVM Output Layer with Stochastic Binary Connect had a test error of 16.3346153846
# SVM Output Layer with Deterministic Binary Connect had a test error of 15.9230769231
