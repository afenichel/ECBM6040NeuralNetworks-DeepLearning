# %%
import numpy
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import pylab

import theano.tensor as T
from theano.tensor.shared_randomstreams import RandomStreams

from final_utils import *
from final_nn import *
from final import *

# Note here we're importing the original author's filter
# plot function to display the features from the first hidden layer. 
# This was a very specific form of plot, thus, I decided to use theirs rather than create our own
# because it would have had to be a near exact copy regardless. No other code was leveraged from
# the author's original work and all other code is our own.

import filter_plot


# %matplotlib inline
# Out:
# Using gpu device 0: GeForce GT 750M (CNMeM is disabled, cuDNN 5004)
# /Users/franciscojavierarceo/anaconda2/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")

# %% [markdown]
# #### MNIST Tests

# %% [markdown]
# ## binary = False, output = Logistic

# %%
W_layer_0, Wb_layer_0 = test_mlp(initial_learning_rate=0.3, final_learning_rate=0.01,
                        L1_reg=0.000, L2_reg=0.000, n_epochs=1000, batch_size=200, 
                        n_hidden=1024, n_hiddenLayers=3, verbose=False, 
                        stochastic=False, binary=False, which_data='mnist', 
                        seedval=12345, outputlayer='Logistic')
# Out:
# Loading mnist data with Logistic output layer
# ... building the model
# Using logistic regression
# ... training
# epoch 1 errors printing to LRout_mnist_errors.csv
# epoch 2 errors printing to LRout_mnist_errors.csv
# epoch 3 errors printing to LRout_mnist_errors.csv
# epoch 4 errors printing to LRout_mnist_errors.csv
# epoch 5 errors printing to LRout_mnist_errors.csv
# epoch 6 errors printing to LRout_mnist_errors.csv
# epoch 7 errors printing to LRout_mnist_errors.csv
# epoch 8 errors printing to LRout_mnist_errors.csv
# epoch 9 errors printing to LRout_mnist_errors.csv
# epoch 10 errors printing to LRout_mnist_errors.csv
# epoch 11 errors printing to LRout_mnist_errors.csv
# epoch 12 errors printing to LRout_mnist_errors.csv
# epoch 13 errors printing to LRout_mnist_errors.csv
# epoch 14 errors printing to LRout_mnist_errors.csv
# epoch 15 errors printing to LRout_mnist_errors.csv
# epoch 16 errors printing to LRout_mnist_errors.csv
# ...

# %%
W = filter_plot.tile_raster_images(W_layer_0.T,(28,28),(4,4),(2, 2))
plt.figure(figsize=(8,8))
plt.imshow(W, cmap = cm.Greys_r)
plt.show()

# %% [markdown]
# ## binary = False, output = SVM

# %%
W_layer_0, Wb_layer_0 = test_mlp(initial_learning_rate=0.3, final_learning_rate=0.01,
                        L1_reg=0.000, L2_reg=0.000, n_epochs=1000, batch_size=200, 
                        n_hidden=1024, n_hiddenLayers=3, verbose=False, 
                        stochastic=False, binary=False, which_data='mnist', 
                        seedval=12345, outputlayer='svm')
# Out:
# Loading mnist data with svm output layer
# ... building the model
# Using Support Vector Machines
# ... training
# epoch 1 errors printing to svmout_mnist_errors.csv
# epoch 2 errors printing to svmout_mnist_errors.csv
# epoch 3 errors printing to svmout_mnist_errors.csv
# epoch 4 errors printing to svmout_mnist_errors.csv
# epoch 5 errors printing to svmout_mnist_errors.csv
# epoch 6 errors printing to svmout_mnist_errors.csv
# epoch 7 errors printing to svmout_mnist_errors.csv
# epoch 8 errors printing to svmout_mnist_errors.csv
# epoch 9 errors printing to svmout_mnist_errors.csv
# epoch 10 errors printing to svmout_mnist_errors.csv
# epoch 11 errors printing to svmout_mnist_errors.csv
# epoch 12 errors printing to svmout_mnist_errors.csv
# epoch 13 errors printing to svmout_mnist_errors.csv
# epoch 14 errors printing to svmout_mnist_errors.csv
# epoch 15 errors printing to svmout_mnist_errors.csv
# epoch 16 errors printing to svmout_mnist_errors.csv
# ...

# %%
W = filter_plot.tile_raster_images(W_layer_0.T,(28,28),(4,4),(2, 2))
plt.figure(figsize=(8,8))
plt.imshow(W, cmap = cm.Greys_r)
plt.show()

# %% [markdown]
# ## binary = True, stochastic=False, output = Logistic

# %%
W_layer_0, Wb_layer_0 = test_mlp(initial_learning_rate=0.3, final_learning_rate=0.01,
                        L1_reg=0.000, L2_reg=0.000, n_epochs=1000, batch_size=200, 
                        n_hidden=1024, n_hiddenLayers=3, verbose=False, 
                        stochastic=False, binary=True, which_data='mnist', 
                        seedval=12345, outputlayer='Logistic')
# Out:
# Loading mnist data with Logistic output layer
# ... building the model
# Using logistic regression
# ... training
# epoch 1 errors printing to LRout_bin_deterministic_mnist_errors.csv
# epoch 2 errors printing to LRout_bin_deterministic_mnist_errors.csv
# epoch 3 errors printing to LRout_bin_deterministic_mnist_errors.csv
# epoch 4 errors printing to LRout_bin_deterministic_mnist_errors.csv
# epoch 5 errors printing to LRout_bin_deterministic_mnist_errors.csv
# epoch 6 errors printing to LRout_bin_deterministic_mnist_errors.csv
# epoch 7 errors printing to LRout_bin_deterministic_mnist_errors.csv
# epoch 8 errors printing to LRout_bin_deterministic_mnist_errors.csv
# epoch 9 errors printing to LRout_bin_deterministic_mnist_errors.csv
# epoch 10 errors printing to LRout_bin_deterministic_mnist_errors.csv
# epoch 11 errors printing to LRout_bin_deterministic_mnist_errors.csv
# epoch 12 errors printing to LRout_bin_deterministic_mnist_errors.csv
# ...

# %%
W = filter_plot.tile_raster_images(W_layer_0.T,(28,28),(4,4),(2, 2))
plt.figure(figsize=(8,8))
plt.imshow(W, cmap = cm.Greys_r)
plt.show()

# %% [markdown]
# ## binary = True, stochastic=True, output = Logistic

# %%
W_layer_0, Wb_layer_0 =  test_mlp(initial_learning_rate=0.3, final_learning_rate=0.01,
                         L1_reg=0.000, L2_reg=0.000, n_epochs=1000, batch_size=200, 
                         n_hidden=1024, n_hiddenLayers=3, verbose=False, 
                         stochastic=True, binary=True, which_data='mnist', 
                         seedval=12345, outputlayer='Logistic')
# Out:
# Loading mnist data with Logistic output layer
# ... building the model
# Using logistic regression
# ... training
# epoch 1 errors printing to LRout_bin_stochastic_mnist_errors.csv
# epoch 2 errors printing to LRout_bin_stochastic_mnist_errors.csv
# epoch 3 errors printing to LRout_bin_stochastic_mnist_errors.csv
# epoch 4 errors printing to LRout_bin_stochastic_mnist_errors.csv
# epoch 5 errors printing to LRout_bin_stochastic_mnist_errors.csv
# epoch 6 errors printing to LRout_bin_stochastic_mnist_errors.csv
# epoch 7 errors printing to LRout_bin_stochastic_mnist_errors.csv
# epoch 8 errors printing to LRout_bin_stochastic_mnist_errors.csv
# epoch 9 errors printing to LRout_bin_stochastic_mnist_errors.csv
# epoch 10 errors printing to LRout_bin_stochastic_mnist_errors.csv
# epoch 11 errors printing to LRout_bin_stochastic_mnist_errors.csv
# epoch 12 errors printing to LRout_bin_stochastic_mnist_errors.csv
# epoch 13 errors printing to LRout_bin_stochastic_mnist_errors.csv
# ...

# %%
W = filter_plot.tile_raster_images(W_layer_0.T,(28,28),(4,4),(2, 2))
plt.figure(figsize=(8,8))
plt.imshow(W, cmap = cm.Greys_r)
plt.show()

# %% [markdown]
# ## binary = True, stochastic=False, output = SVM

# %%
W_layer_0, Wb_layer_0 =  test_mlp(initial_learning_rate=0.3, final_learning_rate=0.01,
                         L1_reg=0.000, L2_reg=0.000, n_epochs=1000, batch_size=200, 
                         n_hidden=1024, n_hiddenLayers=3, verbose=False, 
                         stochastic=False, binary=True, which_data='mnist', 
                         seedval=12345, outputlayer='svm')
# Out:
# Loading mnist data with svm output layer
# ... building the model
# Using Support Vector Machines
# ... training
# epoch 1 errors printing to svmout_bin_deterministic_mnist_errors.csv
# epoch 2 errors printing to svmout_bin_deterministic_mnist_errors.csv
# epoch 3 errors printing to svmout_bin_deterministic_mnist_errors.csv
# epoch 4 errors printing to svmout_bin_deterministic_mnist_errors.csv
# epoch 5 errors printing to svmout_bin_deterministic_mnist_errors.csv
# epoch 6 errors printing to svmout_bin_deterministic_mnist_errors.csv
# epoch 7 errors printing to svmout_bin_deterministic_mnist_errors.csv
# epoch 8 errors printing to svmout_bin_deterministic_mnist_errors.csv
# epoch 9 errors printing to svmout_bin_deterministic_mnist_errors.csv
# epoch 10 errors printing to svmout_bin_deterministic_mnist_errors.csv
# epoch 11 errors printing to svmout_bin_deterministic_mnist_errors.csv
# epoch 12 errors printing to svmout_bin_deterministic_mnist_errors.csv
# ...

# %%
wd0, wbd0 = W_layer_0, Wb_layer_0

# %%
W = filter_plot.tile_raster_images(W_layer_0.T,(28,28),(4,4),(2, 2))
plt.figure(figsize=(8,8))
plt.imshow(W, cmap = cm.Greys_r)
plt.show()

# %% [markdown]
# ## binary = True, stochastic=True, output = SVM

# %%
W_layer_0, Wb_layer_0 =  test_mlp(initial_learning_rate=0.3, final_learning_rate=0.01,
                         L1_reg=0.000, L2_reg=0.000, n_epochs=1000, batch_size=200, 
                         n_hidden=1024, n_hiddenLayers=3, verbose=False, 
                         stochastic=True, binary=True, which_data='mnist', 
                         seedval=12345, outputlayer='svm')
# Out:
# Loading mnist data with svm output layer
# ... building the model
# Using Support Vector Machines
# ... training
# epoch 1 errors printing to svmout_bin_stochastic_mnist_errors.csv
# epoch 2 errors printing to svmout_bin_stochastic_mnist_errors.csv
# epoch 3 errors printing to svmout_bin_stochastic_mnist_errors.csv
# epoch 4 errors printing to svmout_bin_stochastic_mnist_errors.csv
# epoch 5 errors printing to svmout_bin_stochastic_mnist_errors.csv
# epoch 6 errors printing to svmout_bin_stochastic_mnist_errors.csv
# epoch 7 errors printing to svmout_bin_stochastic_mnist_errors.csv
# epoch 8 errors printing to svmout_bin_stochastic_mnist_errors.csv
# epoch 9 errors printing to svmout_bin_stochastic_mnist_errors.csv
# epoch 10 errors printing to svmout_bin_stochastic_mnist_errors.csv
# epoch 11 errors printing to svmout_bin_stochastic_mnist_errors.csv
# epoch 12 errors printing to svmout_bin_stochastic_mnist_errors.csv
# ...

# %%
ws0, wbs0 = W_layer_0, Wb_layer_0

# %%
W = filter_plot.tile_raster_images(W_layer_0.T,(28,28),(4,4),(2, 2))
plt.figure(figsize=(8,8))
plt.imshow(W, cmap = cm.Greys_r)
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy
from scipy import stats
import pandas as pd
import seaborn as sns
mpl.rcParams['figure.figsize']=(12,8)
mpl.rcParams['text.usetex'] = True
mpl.rcParams['font.family'] = 'serif'
sns.set_style('whitegrid')

ws = ws0.reshape(numpy.prod(ws0.shape))
wd = wd0.reshape(numpy.prod(wd0.shape))

# %%
sns.distplot(wd, label='Deterministic', hist=False, color='red', bins=1000)
sns.distplot(ws, label='Stochastic', hist=False, color='green')
plt.title('Histogram of Weights for Stochastic and Binnary Connect', fontsize=14)
plt.ylabel("$f(w)$", fontsize=14)
plt.xlabel('$w$', fontsize=14)
plt.legend(loc='lower center', ncol=2, bbox_to_anchor=(0.5,-0.15), fancybox=True, shadow=True)

# %%
import numpy
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import pylab

import theano.tensor as T
from theano.tensor.shared_randomstreams import RandomStreams

from final_utils import *
from final_nn import *
from final import *

import filter_plot
import pandas as pd

# %matplotlib inline
# Out:
# Using gpu device 0: GeForce GT 750M (CNMeM is disabled, cuDNN 5004)
# /Users/franciscojavierarceo/anaconda2/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")

# %%
perf_files = ['LRout_mnist_errors.csv', 
              'svmout_mnist_errors.csv',
              'LRout_bin_stochastic_mnist_errors.csv', 
              'LRout_bin_deterministic_mnist_errors.csv',
              'LRout_bin_stochastic_mnist_errors.csv',
              'svmout_bin_deterministic_mnist_errors.csv']

perf_filenames = ['Logistic Output Layer without Binary Connect',
                  'SVM Output Layer without Binary Connect',
                  'Logistic Output Layer with Stochastic Binary Connect',
                  'Logistic Output Layer with Deterministic Binary Connect',
                  'SVM Output Layer with Stochastic Binary Connect',
                  'SVM Output Layer with Deterministic Binary Connect'
                 ]
pdic = {}
for i, pfile in enumerate(perf_files):
    pdic['m'+str(i)] = pd.read_csv('output/'+pfile)

# %%
n = 1000
for i, pfile in enumerate(perf_filenames):
    m = 'm'+str(i)
    plt.figure(figsize=(8,5))
    plt.plot(pdic[m].epoch[0:n], pdic[m].test_score[0:n], label='Test')
    plt.plot(pdic[m].epoch[0:n], pdic[m].this_validation_loss[0:n], label='Validation')
    plt.plot(pdic[m].epoch[0:n], pdic[m].this_training_loss[0:n], label='Training')
    plt.title("MNIST Model performance \n"+pfile)
    plt.ylabel('Classification Error (%)')
    plt.xlabel('Number of epochs')
    plt.legend()
    plt.ylim([0.00,0.04])
    plt.grid()
    plt.show()

# %%
for (filex, filename) in zip(perf_filenames, perf_files):
    df = pd.read_csv('output/'+filename)
    print filex,'had a test error of' , df.ix[df.this_validation_loss.argmin(),'test_score']*100
# Out:
# Logistic Output Layer without Binary Connect had a test error of 1.92
# SVM Output Layer without Binary Connect had a test error of 2.4
# Logistic Output Layer with Stochastic Binary Connect had a test error of 1.86
# Logistic Output Layer with Deterministic Binary Connect had a test error of 1.83
# SVM Output Layer with Stochastic Binary Connect had a test error of 1.86
# SVM Output Layer with Deterministic Binary Connect had a test error of 2.36
